# %%
# %matplotlib notebook

# %%
import brian2
import csv
import matplotlib
import matplotlib.pyplot as plt

# %%
def csv_to_raster(file_name,plot_title):
   with open(file_name+'.csv', 'r') as csv_file:
    data = list(csv.reader(csv_file, delimiter=','))
    spike_idx = [int(idx) for idx in data[0]]
    spike_times = [float(time[:-2]) for time in data[1]] # remove last 2 charactes from times as these will be 'ms' to signify milliseconds
    fig = plt.figure(dpi=150)
    matplotlib.rcParams['figure.figsize'] = [6.5, 4]
    plt.plot(spike_times, spike_idx, 'ok', markersize=0.5)
    plt.xlabel('Time (ms)')
    plt.ylabel('Neuron index')
    plt.title(plot_title)
    # plt.savefig(file_name+'.png',dpi=500)

# %%
csv_to_raster('../simulation_data/layer_1_excitatory_spikes','Layer 1 excitatory neurons')
# Out:
# <img src="data:image/png;base64,..." width="974.4166666666667">

# %%
csv_to_raster('simulation_data/layer_1_inhibitory_spikes','Layer 1 inhibitory neurons')
# Out:
# <img src="data:image/png;base64,..." width="974.4166666666667">

# %%
csv_to_raster('simulation_data/layer_2_excitatory_spikes','Layer 2 excitatory neurons')
# Out:
# <img src="data:image/png;base64,..." width="974.4166666666667">

# %%
csv_to_raster('simulation_data/layer_2_inhibitory_spikes','Layer 2 inhibitory neurons')
# Out:
# <img src="data:image/png;base64,..." width="974.4166666666667">

# %%
csv_to_raster('simulation_data/layer_3_excitatory_spikes','Layer 3 excitatory neurons')
# Out:
# <img src="data:image/png;base64,..." width="974.4166666666667">

# %%
csv_to_raster('simulation_data/layer_3_inhibitory_spikes','Layer 3 inhibitory neurons')
# Out:
# <img src="data:image/png;base64,..." width="974.4166666666667">

# %%
csv_to_raster('simulation_data/layer_4_excitatory_spikes','Layer 4 excitatory neurons')
# Out:
# <img src="data:image/png;base64,..." width="NaN">

# %%
csv_to_raster('simulation_data/layer_4_inhibitory_spikes','Layer 4 inhibitory neurons')
# Out:
# <img src="data:image/png;base64,..." width="974.4166666666667">
